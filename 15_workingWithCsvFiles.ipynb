# %% [markdown]
# Data Gathering : Data gathering is the process of collecting and measuring information from various sources to analyze, draw conclusions, and make decisions.
# 1. csv file
# 2. JSON/SQL
# 3. fetch Api
# 4. web scraping

# %% [markdown]
# comma seprated value : csv
# tab seprated value   : tsv
# today CSV...

# %%
import pandas as pd

# %%
# Opening a local csv files 
df = pd.read_csv('./DataSets/15_placement.csv')
df.head()
# Out:
#        Unnamed: 0  cgpa   iq  placement
# 0 6.8       123.0     1  0.0        9.0
# 1 5.9       106.0     0  NaN        NaN
# 2 5.3       121.0     0  NaN        NaN
# 3 7.4       132.0     1  NaN        NaN
# 4 5.8       142.0     0  NaN        NaN

# %% [markdown]
# opening a csv file from an URL

# %%
import pandas as pd
import requests
from io import StringIO

url = "http://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Fireforx/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# Sep parameter : The sep parameter in pd.read_csv() specifies the delimiter that separates the columns in the file. By default, it's set to a comma (,), but if you're working with a tab-separated values file (like a .tsv), you use sep='\t', where \t represents a tab character.
#
# A delimiter is a character or sequence of characters used to separate values in a text file :
# CSV(,)
# TSV(\t)

# %%
pd.read_csv('./DataSets/15_weather.tsv', sep='\t').head()

# If data colonm name is not defined then name
# pd.read_csv('./DataSets/15_weather.tsv', sep='\t' names=['MaxTemp', 'Rainfall', etc all column names])
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# index_col parameter : convert the column into index

# %%
pd.read_csv('weather.tsv', sep='\t', index_col='MinTemp')
# Out:
#          MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  WindGustSpeed  \
# MinTemp
# 8.0         24.3       0.0          3.4       6.3          NW           30.0
# 14.0        26.9       3.6          4.4       9.7         ENE           39.0
# 13.7        23.4       3.6          5.8       3.3          NW           85.0
# 13.3        15.5      39.8          7.2       9.1          NW           54.0
# 7.6         16.1       2.8          5.6      10.6         SSE           50.0
# ...          ...       ...          ...       ...         ...            ...
# 9.0         30.7       0.0          7.6      12.1         NNW           76.0
# 7.1         28.4       0.0         11.6      12.7           N           48.0
# 12.5        19.9       0.0          8.4       5.3         ESE           43.0
# 12.5        26.9       0.0          5.0       7.1          NW           46.0
# 12.3        30.2       0.0          6.0      12.6          NW           78.0
#
# ...

# %% [markdown]
# Header parameter : if your header treat as a rows

# %%
pd.read_csv('weather.tsv', sep='\t', header=1)
# Out:
#         8  24.3     0   3.4   6.3   NW    30   SW NW.1     6  ...  29  1019.7  \
# 0    14.0  26.9   3.6   4.4   9.7  ENE  39.0    E    W   4.0  ...  36  1012.4
# 1    13.7  23.4   3.6   5.8   3.3   NW  85.0    N  NNE   6.0  ...  69  1009.5
# 2    13.3  15.5  39.8   7.2   9.1   NW  54.0  WNW    W  30.0  ...  56  1005.5
# 3     7.6  16.1   2.8   5.6  10.6  SSE  50.0  SSE  ESE  20.0  ...  49  1018.3
# 4     6.2  16.9   0.0   5.8   8.2   SE  44.0   SE    E  20.0  ...  57  1023.8
# ..    ...   ...   ...   ...   ...  ...   ...  ...  ...   ...  ...  ..     ...
# 360   9.0  30.7   0.0   7.6  12.1  NNW  76.0  SSE   NW   7.0  ...  15  1016.1
# 361   7.1  28.4   0.0  11.6  12.7    N  48.0  NNW  NNW   2.0  ...  22  1020.0
# 362  12.5  19.9   0.0   8.4   5.3  ESE  43.0  ENE  ENE  11.0  ...  47  1024.0
# 363  12.5  26.9   0.0   5.0   7.1   NW  46.0  SSW  WNW   6.0  ...  39  1021.0
# 364  12.3  30.2   0.0   6.0  12.6   NW  78.0   NW  WNW  31.0  ...  13  1009.6
#
# ...

# %% [markdown]
# use_cols parameter :  if you only specific columns for filtering

# %%
pd.read_csv('weather.tsv', sep='\t', usecols=['MinTemp', 'MaxTemp', 'Rainfall'])
# Out:
#      MinTemp  MaxTemp  Rainfall
# 0        8.0     24.3       0.0
# 1       14.0     26.9       3.6
# 2       13.7     23.4       3.6
# 3       13.3     15.5      39.8
# 4        7.6     16.1       2.8
# ..       ...      ...       ...
# 361      9.0     30.7       0.0
# 362      7.1     28.4       0.0
# 363     12.5     19.9       0.0
# 364     12.5     26.9       0.0
# 365     12.3     30.2       0.0
#
# [366 rows x 3 columns]

# %% [markdown]
# skiprows/nrows parameter

# %%
pd.read_csv('Weather.tsv', sep='\t', skiprows=[1,5])
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0       14.0     26.9       3.6          4.4       9.7         ENE
# 1       13.7     23.4       3.6          5.8       3.3          NW
# 2       13.3     15.5      39.8          7.2       9.1          NW
# 3        6.2     16.9       0.0          5.8       8.2          SE
# 4        6.1     18.2       0.2          4.2       8.4          SE
# ..       ...      ...       ...          ...       ...         ...
# 359      9.0     30.7       0.0          7.6      12.1         NNW
# 360      7.1     28.4       0.0         11.6      12.7           N
# 361     12.5     19.9       0.0          8.4       5.3         ESE
# 362     12.5     26.9       0.0          5.0       7.1          NW
# 363     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             39.0          E          W           4.0  ...           36
# ...

# %% [markdown]
# nrows : 100 rows only show

# %%
pd.read_csv('Weather.tsv', sep='\t', nrows=100)
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0       8.0     24.3       0.0          3.4       6.3          NW
# 1      14.0     26.9       3.6          4.4       9.7         ENE
# 2      13.7     23.4       3.6          5.8       3.3          NW
# 3      13.3     15.5      39.8          7.2       9.1          NW
# 4       7.6     16.1       2.8          5.6      10.6         SSE
# ..      ...      ...       ...          ...       ...         ...
# 95     18.2     22.6       1.8          8.0       0.0         ENE
# 96     16.8     22.8       9.0          2.8       0.3         ESE
# 97     13.6     27.4       1.0          2.8       8.0           W
# 98     14.5     24.2       0.0          6.8       5.9         SSW
# 99     12.4     19.9      16.2          5.4       5.6         ENE
#
#     WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0              30         SW         NW             6  ...           29
# ...

# %% [markdown]
# encoding parameter : some dataset has not encoding UTF8 use to change encoding
# UnicodeDecodeError  : this error occure.

# %%
pd.read_csv('Sample_Superstore.csv', encoding='latin-1')
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# dtypes parameter : for memory saving

# %%
pd.read_csv('Sample_Superstore.csv', encoding='latin-1').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df = pd.read_csv('Sample_Superstore.csv', encoding='latin-1', dtype={'Quantity':float})
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
pd.read_csv('Sample_Superstore.csv', encoding='latin-1', dtype={'Quantity':float}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# in pandas object means : string
# Handing Dates : days shows bydefault object, to convert date time

# %%
pd.read_csv('customersSaledata-10000.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              10000 non-null  int64
#  1   Customer Id        10000 non-null  object
#  2   First Name         10000 non-null  object
#  3   Last Name          10000 non-null  object
#  4   Company            10000 non-null  object
#  5   City               10000 non-null  object
#  6   Country            10000 non-null  object
#  7   Phone 1            10000 non-null  object
#  8   Phone 2            10000 non-null  object
#  9   Email              10000 non-null  object
#  10  Subscription Date  10000 non-null  object
#  11  Website            9998 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 937.6+ KB

# %%
pd.read_csv('customersSaledata-10000.csv', parse_dates=['Subscription Date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              10000 non-null  int64
#  1   Customer Id        10000 non-null  object
#  2   First Name         10000 non-null  object
#  3   Last Name          10000 non-null  object
#  4   Company            10000 non-null  object
#  5   City               10000 non-null  object
#  6   Country            10000 non-null  object
#  7   Phone 1            10000 non-null  object
#  8   Phone 2            10000 non-null  object
#  9   Email              10000 non-null  object
#  10  Subscription Date  10000 non-null  datetime64[ns]
#  11  Website            9998 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 937.6+ KB

# %% [markdown]
# converters : i want to short the name (FIrst Name to (Name))

# %%
def rename(name):
    if name == "Callahan":
        return "ch"
    else:
        return "Not change"

# %%
rename('Callahan')
# Out:
# 'ch'

# %%
pd.read_csv('customersSaledata-10000.csv', converters={'Last Name':rename})
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather          ch              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina  Not change  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana  Not change               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty  Not change          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen  Not change              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan  Not change            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah  Not change               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy  Not change                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan  Not change                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Not change              Burns-Holden
#
# ...

# %% [markdown]
# na_vales parameter : if there is - (hyphen) or any value that you want to show as a  null then we use

# %%
pd.read_csv('customersSaledata-10000.csv', na_values=['Heather'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.read_csv('customersSaledata-10000.csv', na_values=['Heather'])
#
# NameError: name 'pd' is not defined

# %% [markdown]
# loding a huge dataset in chunk

# %%
dfs = pd.read_csv('customersSaledata-10000.csv', chunksize=3000)

for chunks in dfs:
    print(chunks.shape)
# Out:
# (3000, 12)
# (3000, 12)
# (3000, 12)
# (1000, 12)
