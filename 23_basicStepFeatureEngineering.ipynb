# %% [markdown]
# intern apply....
# pythin (DSA),,,,,,,,,,,,,,,, start afetr FE and some ago
#
#
# 60 at least then understanding bst//   to ml,,,
# communication....

# %% [markdown]
# Feature engineering is a crucial step in the machine learning pipeline. It involves transforming raw data into features that make machine learning algorithms more effective.
# Here are the key steps in feature engineering:

# %% [markdown]
# Feature engineering can indeed take up a significant portion of a machine learning project—often around 30% or even more of the total project time.
# Feature engineering is not just a process; it's more like an art or a problem-solving technique. Everyone has their own unique approach to performing feature engineering.
#
# "features" typically refer to the input variables or columns in your dataset.
# It is said about feature engineering that if you provide a poor algorithm with excellent features and a powerful algorithm with poor features, the one with the poor features will perform worse.

# %% [markdown]
# ,
# ,
# ,
# ,
# ,
# ,
# ,

# %% [markdown]
# Feature Scaling :  (copy)
# Standardization
#
# purchased (0(no),1(yes)) classification problems.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('23_Social_Network_Ads.csv')
df = df.iloc[:, 2:]
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 252   48           134000          1
# 165   18            86000          0
# 321   53            82000          1
# 142   35            59000          0
# 238   46            82000          0

# %% [markdown]
# If you want to Feature scaling, Then you should always train and split, it is recommended.
# df.drop('Purchased', axis=1) :: That means it will leave 'Purchased' column and put the 'age' and 'salary' in the 'x_train'.
# random_state=0 ensures that the same 30% of data will be used for the test set every time this line is executed.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased', axis=1), df['Purchased'], test_size=0.3, random_state=0)


X_train.shape, X_test.shape
# Out:
# ((280, 2), (120, 2))

# %% [markdown]
# Standard Scalar class :  will take each value and transform it, using formula.
# If you want, you can create the class yourself, but it's given. then why gan. masti.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# fit the scalar to the train set, it will learn the parameter, fit means calculate both column (age, salary) mean and SD of X_train.  
scaler.fit(X_train)

# transforms train and test sets 
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
scaler.mean_
# Out:
# array([3.78642857e+01, 6.98071429e+04])

# %%
X_train.head(2)
# Out:
#      Age  EstimatedSalary
# 92    26            15000
# 223   60           102000

# %% [markdown]
# sent the dataframe x-train, x_train_scaled got numpy

# %%
X_train_scaled
# Out:
# array([[-1.1631724 , -1.5849703 ],
#        [ 2.17018137,  0.93098672],
#        [ 0.0133054 ,  1.22017719],
#        [ 0.20938504,  1.07558195],
#        [ 0.40546467, -0.48604654],
#        [-0.28081405, -0.31253226],
#        [ 0.99370357, -0.8330751 ],
#        [ 0.99370357,  1.8563962 ],
#        [ 0.0133054 ,  1.24909623],
#        [-0.86905295,  2.26126285],
#        [-1.1631724 , -1.5849703 ],
#        [ 2.17018137, -0.80415605],
#        [-1.35925203, -1.46929411],
#        [ 0.40546467,  2.2901819 ],
#        [ 0.79762394,  0.75747245],
#        [-0.96709276, -0.31253226],
#        [ 0.11134522,  0.75747245],
#        [-0.96709276,  0.55503912],
#        [ 0.30742485,  0.06341534],
#        [ 0.69958412, -1.26686079],
#        [-0.47689368, -0.0233418 ],
#        [-1.7514113 ,  0.3526058 ],
#        [-0.67297331,  0.12125343],
#        [ 0.40546467,  0.29476771],
#        [-0.28081405,  0.06341534],
#        [-0.47689368,  2.2901819 ],
#        [ 0.20938504,  0.03449629],
# ...

# %% [markdown]
# convert X_train_scale into dataframe

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

X_train_scaled.head()
# Out:
#         Age  EstimatedSalary
# 0 -1.163172        -1.584970
# 1  2.170181         0.930987
# 2  0.013305         1.220177
# 3  0.209385         1.075582
# 4  0.405465        -0.486047

# %%
# Original DataSet
np.round(X_train.describe(), 1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.9          69807.1
# std     10.2          34641.2
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %% [markdown]
# mean=0, SD=1 scaling occure

# %%
np.round(X_train_scaled.describe(), 1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.8              0.5
# max      2.2              2.3

# %% [markdown]
# Effect of Scaling
# (0,0)mean=0, SD=1

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")

ax2.scatter(X_train_scaled['Age'], X_train_scaled['EstimatedSalary'], color='red')
ax2.set_title("After Scaling")

plt.show()

# %% [markdown]
# PDA
# In first graph both(salary,age) are so far not any comparision.
# In second graph(after) both are so closted comparable, Those who can perform what they think, Both are equal, the algorithm will perform better.

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

ax1.set_title("Before scaling")
sns.kdeplot(X_train['Age'], ax=ax1)
sns.kdeplot(X_test['EstimatedSalary'], ax=ax1)

ax2.set_title("After scaling")
sns.kdeplot(X_train_scaled['Age'], ax=ax2)
sns.kdeplot(X_test_scaled['EstimatedSalary'], ax=ax2)
# Out:
# <Axes: title={'center': 'After scaling'}, xlabel='Age', ylabel='Density'>

# %% [markdown]
# Comparision of Distributions, indevisually : only for understanding more plots..
# Distribution same only scale change mean=0, SD=1.

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(12,5))

ax1.set_title('Age Distribution Before Scaling')
sns.kdeplot(X_train['Age'], ax=ax1)

ax2.set_title('Age Distribution After standard Scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2)

plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(12,5))

ax1.set_title('Salary Distribution Before Scaling')
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)

ax2.set_title('Salary Distribution After standard Scaling')
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)

plt.show()

# %% [markdown]
# # Why scalling is important?
#
# To check we use LogisticRegression Algorithm.
# logistic regression me value scale karke dena is import nhi to result aachenhi aayenge
#
#
# After scaling, value increase means better performance
# Actual 0.875
# scaled 0.8666666666666667

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(X_train, y_train)
lr_scaled.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)
y_pred_scaled = lr_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score
print("Actual", accuracy_score(y_test, y_pred))
print('scaled', accuracy_score(y_test, y_pred_scaled))
# Out:
# Actual 0.875
# scaled 0.8666666666666667

# %% [markdown]
# ,
# ,
# ,
# ,
# ,

# %% [markdown]
# Scaling is beneficial in some algorithms, not all.Only I think about distance.
#
# Decision Tree
# Scaling does not make any difference in DT.

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()

# %%
dt.fit(X_train, y_train)
dt_scaled.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)
y_pred_scaled = dt_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score
print("Actual", accuracy_score(y_test, y_pred))
print('scaled', accuracy_score(y_test, y_pred_scaled))
# Out:
# Actual 0.875
# scaled 0.8666666666666667

# %% [markdown]
# ,
# ,
# ,
# ,

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %% [markdown]
# Effect of Outlier
#
# This will add the new rows (with 'Age', 'EstimatedSalary', and 'Purchased' columns) to the original df DataFrame. However, in the recent versions of Pandas (from 2.0 onward), df.append() is deprecated and you should use pd.concat() instead. Here's the equivalent code using concat:
#
# Append new outliers

# %%
df = pd.concat([df, pd.DataFrame({'Age':[5,90,95], 'EstimatedSalary':[1000,250000,350000], 'Purchased':[0,1,1]})], ignore_index=True)
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 398   36            33000          0
# 399   49            36000          1
# 400    5             1000          0
# 401   90           250000          1
# 402   95           350000          1
#
# [403 rows x 3 columns]

# %% [markdown]
# There are three outilers

# %%
plt.scatter(df['Age'], df['EstimatedSalary'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased', axis=1), df['Purchased'], test_size=0.3, random_state=0)

X_train.shape, X_test.shape
# Out:
# ((282, 2), (121, 2))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_train_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %% [markdown]
# X_train data only two outliers shown here, One outlier went away during training.
# Outliers are still outliers, outliers will have to be handled explicitly.

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")

ax2.scatter(X_train_scaled['Age'], X_train_scaled['EstimatedSalary'], color='red')
ax2.set_title("After Scaling")
plt.show()
